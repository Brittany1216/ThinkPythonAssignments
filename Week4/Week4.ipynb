# %% [markdown]
# <a href="https://colab.research.google.com/github/Brittany1216/ThinkPythonAssignments/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
def print_bio():
    print("Name: Brittany Curry, Age: 29, Goal: Learn Python.")
def print_famous():
    print("Name: Robin Williams, Age: 63, Goal: Make people laugh.")
def print_fictional():
    print("Name: Leroy Gibbs, Age: 67, Goal: Solve naval crimes.")


# PROGRAM LOGIC
# Print top border
print("*" * 25)
print_bio()
# Print bottom border
print("*" * 25)

# Print top border
print("*" * 25)
print_famous()
# Print bottom border
print("*" * 25)

# Print top border
print("*" * 25)
print_fictional()
# Print botttom border
print("*" * 25)
# Out:
# *************************
# Name: Brittany Curry, Age: 29, Goal: Learn Python.
# *************************
# *************************
# Name: Robin Williams, Age: 63, Goal: Make people laugh.
# *************************
# *************************
# Name: Leroy Gibbs, Age: 67, Goal: Solve naval crimes.
# *************************
