# %% [markdown]
# <a href="https://colab.research.google.com/github/Brittany1216/ThinkPythonAssignments/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# Def print_bio with three parameters: name, age, and goal.
# Inside the function, use string multiplication (*) for a border line.
# Print the bio details using the parameter names.

# PROGRAM LOGIC
# Call print_bio using my own info.
# Call print_bio using [Name of Famous Person].
# Call print_bio using [Name of Fictional Character].
