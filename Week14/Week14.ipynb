# %% [markdown]
# <a href="https://colab.research.google.com/github/Brittany1216/ThinkPythonAssignments/blob/main/Week14/Week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS

# CLASS DEFINITIONS
# 1. Create _int_ class
class Book:
  def __init__(self, title, author):
#    - Must accept a title and author
#    - Include third attribut called is_available
    self.title = title
    self.author = author
    self.is_available = True
# 2. Use _str_ method
#    - Return "The Great Gatsby by F. Scott Fitzgerald - Available"
  def __str__(self):
    status = "Available" if self.is_available else "Checked out"
    return f"{self.title} by {self.author} - {status}"
# 3. Create checkout() method
  def checkout(self):
#    - Sets is_available to false
    self.is_available = False
# 4. Create return_book method
  def return_book(self):
#    - Sets is_available to true
    self.is_available = True

# PROGRAM LOGIC
# 1. Create at least two separate instances of the Book class
book1 = Book('The Great Gatsby', 'F. Scott Fitzgerald')
book2 = Book('The Diary of a Young Girl', 'Anne Frank')
#    -Print the status of both books.
print('-Library Status')
print(book1)
print(book2)
# 2. Check out one of the books using your method.
input('-Do you want to check out book 1 or book 2?')
# 3. Print both books again to show that the status of the specific object has changed.
print('-Updated Status')
print(book1)
print(book2)
# 4. Return the book using your method
book1.return_book()
print(book1)
# Out:
# -Library Status
# The Great Gatsby by F. Scott Fitzgerald - Available
# The Diary of a Young Girl by Anne Frank - Available
# -Do you want to check out book 1 or book 2?1
# -Updated Status
# The Great Gatsby by F. Scott Fitzgerald - Available
# The Diary of a Young Girl by Anne Frank - Available
# The Great Gatsby by F. Scott Fitzgerald - Available
