# %% [markdown]
# <a href="https://colab.research.google.com/github/Brittany1216/ThinkPythonAssignments/blob/main/Week16/Week16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# 1. Define category
#    - User must enter type of category
# 2. Define vendor
#    - User must enter type of store
# 3. Define amount
#    - User must enter amount
# 4. Define date
#    - User must enter a date


# PROGRAM LOGIC
# 1. User can enter as many records in one use
#    - Create an infinite while loop
# 2. User can can request sum of all expenses, filtered by category, and by specific vendor
#    - Get user input
# 3. User can toggle between adding new data and requesting totals
#    - Create an end
