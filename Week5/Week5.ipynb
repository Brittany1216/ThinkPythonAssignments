# %% [markdown]
# <a href="https://colab.research.google.com/github/Brittany1216/ThinkPythonAssignments/blob/main/Week5/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
def calculate_ticket(age, hour):
  if age <= 12 or age >=65:
      base_price = 10
  else:
      base_price = 12
  if hour < 17:
      discount = 2
      final_price = base_price - discount
  else:
      final_price = base_price

  print(f'Your ticket price is ${final_price:.2f}.')

# PROGRAM LOGIC
user_age = int(input('Please enter your age:'))
user_hour = int(input('Enter the movie hour in 24-hr format (eg., 16 for 4 pm, 22 for 10 pm):'))

calculate_ticket(70, 14)
# Out:
# Please enter your age:70
# Enter the movie hour in 24-hr format (eg., 16 for 4 pm, 22 for 10 pm):14
# Your ticket price is $8.00.
