# %% [markdown]
# <a href="https://colab.research.google.com/github/Brittany1216/ThinkPythonAssignments/blob/main/Week13/Week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: journal.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# 1. Define write_entry
def write_entry(filename, entry):
#    - Accept a filename and a string as parameters
#    - Close when finished
    with open('journal.txt', 'a') as file:
        file.write(entry + '\n')
    print('Entry written to journal.')

# 2. Define read_journal
def read_journal(filename='journal.txt'):
#    - Read entire contents and print so users can see their past entries
    try:
        with open(filename, 'r') as file:
            content = file.read()
            print('--- Journal Entries ---')
            print(content)
    except FileNotFoundError:
        print(f'Error: The file "{filename}" does not exist yet. Please write an entry first.')
# PROGRAM LOGIC
# 1. Ask user if they want to write a new entry or read their journal
input('Do you want to write a new entry or read your journal? (W/R): ')
#    - W for write a new entry and R for read journal
#    - If W ask for their thoughts and call write_entry
write_entry('journal.txt', user_entry)
#    - If R call read_journal
read_journal('journal.txt')
# 2. Make a while loop so the user can keep using it until they type 'Quit'
if __name__ == "__main__":
    while True:
        print('**** Daily Journal ****')
        print('1. Write New Journal Entry')
        print('2. Done')
        choice = input('Select an option (1-2): ')

        if choice == '1':
            user_entry = input('Enter your journal entry: ')
            write_entry('journal.txt', user_entry)
        elif choice == '2':
            break
        else:
            print("Invalid choice, try again.")
# Out:
# Do you want to write a new entry or read your journal? (W/R): r
# Entry written to journal.
# --- Journal Entries ---
# First journal entry
# Second journal entry
# Second journal entry
# I think it's working!!!!
# I think it's working!!!!
# I think it's working!!!!
#
# **** Daily Journal ****
# 1. Write New Journal Entry
# 2. Done
# Select an option (1-2): 2
